# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/work/step02/height.txt'
xs = np.loadtxt(path)
print(xs.shape)
# Out:
# (25000,)

# %%
plt.hist(xs, bins='auto', density=True)
plt.xlabel('Hegiht (cm)')
plt.ylabel('Probability Density')
plt.show()

# %%
mu = np.mean(xs)
sigma = np.std(xs)
print(mu, sigma)
# Out:
# 172.70250853667997 4.830167473396299

# %%
def normal(x, mu=0, sigma=1):
    y = 1 / (np.sqrt(2 * np.pi) * sigma) * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))
    return y

# %%
x = np.linspace(150, 190, 1000)
y = normal(x, mu, sigma)

plt.hist(xs, bins='auto', density=True)
plt.plot(x, y)
plt.show()

# %%
samples = np.random.normal(mu, sigma, 10000)
plt.hist(xs, bins='auto', density=True, alpha=0.7, label='original')
plt.hist(samples, bins='auto', density=True, alpha=0.7, label='generated')
plt.show()

# %%
from scipy.stats import norm

# %%
x = 1.0
p = norm.cdf(x, loc=0, scale=1)
p
# Out:
# 0.8413447460685429

# %%
p1 = norm.cdf(160, mu, sigma)
p2 = norm.cdf(180, mu, sigma)
p1, 1 - p2
# Out:
# (0.004271406830855, 0.06541774339950823)
